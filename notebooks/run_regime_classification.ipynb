# %% [markdown]
# ## Run Regime Classification
# Run regime classification for all CAMELS basins

# %%
import numpy as np
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor
import pandas as pd
import warnings
import io
import re  # For regular expression operations

# Suppress warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Load the Basin IDs
#ids = ["2327", "2498"]

file_path = '../CH_data/gauge_coordinates.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)
gauge_id = data['gauge_id']
ids = gauge_id.tolist()


def clean_data(raw_data):
    """
    Clean the extracted data list by removing unwanted elements and parentheses.
    """
    cleaned_data = []
    
    for item in raw_data:
        if item == '0' or item == 'POINT':
            continue  # Skip '0' and 'POINT'
        if '(' in item:  # For latitude
            item = item.replace('(', '')  # Remove '('
        if ')' in item:  # For longitude
            item = item.replace(')', '')  # Remove ')'
        
        cleaned_data.append(item)  # Add the cleaned item to the list
    
    return cleaned_data

def extract_data_array(raw_output):
    """
    Extract data from the raw output string into an array without headers.
    """
    # Split the raw output into lines
    lines = raw_output.strip().splitlines()
    
    # Use a regex to capture only the relevant lines for DataFrame
    data_lines = []
    
    for line in lines:
        # Ignore lines that don't start with a valid pattern
        if re.match(r'^\d+', line) or 'CAMELS' in line:  # Keeping lines starting with digits or containing 'CAMELS'
            # Remove unwanted characters and split into elements
            cleaned_line = re.sub(r'\\', '', line)  # Remove backslashes
            elements = cleaned_line.split()  # Split by whitespace
            data_lines.append(elements)

    # Flatten the list of lists into a single list, removing headers
    return [item for sublist in data_lines for item in sublist]

def run_regime_classification(ids):
    # Load the rc_simulation Notebook
    notebook_file = '../notebooks/1_RegimeClassification.ipynb'
    
    # Initialize lists to store all results
    regime_annualmax_data = []
    regime_POT_data = []
    regime_COM_data = []

    for basin_id in ids:
        print(f"Processing Basin ID: {basin_id}")  # Log the current Basin ID
        with open(notebook_file) as f:
            nb = nbformat.read(f, as_version=4)

        # Set basin_id in the notebook as test_basin_id
        replacement_done = False  # Flag to track if replacement is done
        
        for cell in nb.cells:
            if cell.cell_type == 'code' and not replacement_done:
                # Search for the line that contains 'test_basin_id ='
                if 'test_basin_id' in cell.source:
                    # Replace the entire line where test_basin_id is defined
                    cell_lines = cell.source.split('\n')
                    for i, line in enumerate(cell_lines):
                        if 'test_basin_id' in line:
                            # Replace the line with the new basin_id assignment
                            cell_lines[i] = f"test_basin_id = '{basin_id}'  # Set basin_id for testing"
                            replacement_done = True
                            break  # Exit the loop after the first replacement
                    # Re-join the cell source code
                    cell.source = '\n'.join(cell_lines)

        # Execute the notebook
        ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
        try:
            ep.preprocess(nb, {'metadata': {'path': './'}})

            # Extract the outputs from the last 3 cells
            regime_annualmax_gdf = nb.cells[-3].outputs[0]['data']['text/plain']
            regime_POT_gdf = nb.cells[-2].outputs[0]['data']['text/plain']
            regime_COM_gdf = nb.cells[-1].outputs[0]['data']['text/plain']

            # Debug: Print raw outputs
            print("\nRaw outputs:")
            print("Annual Max:", regime_annualmax_gdf)
            print("POT:", regime_POT_gdf)
            print("COM:", regime_COM_gdf)

            # Extract data as arrays without headers
            annualmax_data = extract_data_array(regime_annualmax_gdf)
            POT_data = extract_data_array(regime_POT_gdf)
            COM_data = extract_data_array(regime_COM_gdf)

            # Clean the extracted data
            cleaned_annualmax_data = clean_data(annualmax_data)
            cleaned_POT_data = clean_data(POT_data)
            cleaned_COM_data = clean_data(COM_data)

            # Debug: Print cleaned arrays
            print("\nCleaned Data Arrays:")
            print("Annual Max Data:\n", cleaned_annualmax_data)
            print("POT Data:\n", cleaned_POT_data)
            print("COM Data:\n", cleaned_COM_data)

            # Append the current basin's cleaned data to the final results
            regime_annualmax_data.append(cleaned_annualmax_data)  # Add Basin ID
            regime_POT_data.append(cleaned_POT_data)  # Add Basin ID
            regime_COM_data.append(cleaned_COM_data)  # Add Basin ID

            print(f"Results for Basin ID {basin_id} were successfully processed.")

        except Exception as e:
            print(f"Error while executing the notebook for Basin ID {basin_id}: {e}")

    # Save the results as CSV files with headers
    header = 'source,Station_ID,lon,lat,circular_stats_theta_rad,circular_stats_regularity,mean_peak_doy'
    #np.savetxt('../CH_data/CH_output_data/regime_annualmax_data.csv', regime_annualmax_data, delimiter=',', fmt='%s')
    np.savetxt('../CH_data/CH_output_data/regime_annualmax_data.csv', regime_annualmax_data, delimiter=',', fmt='%s', header=header, comments='')
    np.savetxt('../CH_data/CH_output_data/regime_POT_data.csv', regime_POT_data, delimiter=',', fmt='%s', header=header, comments='')
    np.savetxt('../CH_data/CH_output_data/regime_COM_data.csv', regime_COM_data, delimiter=',', fmt='%s', header=header, comments='')

    print("All results have been successfully exported as CSV files.")

# Start the function
run_regime_classification(ids)
# Out:
# Processing Basin ID: 2004
# Error while executing the notebook for Basin ID 2004: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2007
# Error while executing the notebook for Basin ID 2007: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2009
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2009  POINT (6.88862 46.34956)                  3.142985
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.812753     182.717946
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2009  POINT (6.88862 46.34956)                  3.206467
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.883483      186.34427
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2009  POINT (6.88862 46.34956)                  2.608728
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.944336     151.649763
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2009', '6.88862', '46.34956', '3.142985', '0.812753', '182.717946']
# POT Data:
#  ['CAMELS', '2009', '6.88862', '46.34956', '3.206467', '0.883483', '186.34427']
# COM Data:
#  ['CAMELS', '2009', '6.88862', '46.34956', '2.608728', '0.944336', '151.649763']
# Results for Basin ID 2009 were successfully processed.
# Processing Basin ID: 2011
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2011  POINT (7.35791 46.21909)                  3.233816
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.855396     187.991602
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2011  POINT (7.35791 46.21909)                  3.268157
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.912624     189.933494
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2011  POINT (7.35791 46.21909)                  2.966065
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.952723     172.421356
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2011', '7.35791', '46.21909', '3.233816', '0.855396', '187.991602']
# POT Data:
#  ['CAMELS', '2011', '7.35791', '46.21909', '3.268157', '0.912624', '189.933494']
# COM Data:
#  ['CAMELS', '2011', '7.35791', '46.21909', '2.966065', '0.952723', '172.421356']
# Results for Basin ID 2011 were successfully processed.
# Processing Basin ID: 2014
# Error while executing the notebook for Basin ID 2014: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2016
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2016  POINT (8.19488 47.48254)                  2.021483
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.147696     117.316444
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2016  POINT (8.19488 47.48254)                  2.393943
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.321463     139.017123
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2016  POINT (8.19488 47.48254)                  1.896122
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.898668     110.227684
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2016', '8.19488', '47.48254', '2.021483', '0.147696', '117.316444']
# POT Data:
#  ['CAMELS', '2016', '8.19488', '47.48254', '2.393943', '0.321463', '139.017123']
# COM Data:
#  ['CAMELS', '2016', '8.19488', '47.48254', '1.896122', '0.898668', '110.227684']
# Results for Basin ID 2016 were successfully processed.
# Processing Basin ID: 2017
# Error while executing the notebook for Basin ID 2017: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2018
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2018  POINT (8.27127 47.42103)                  3.130889
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.750041      182.01951
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2018  POINT (8.27127 47.42103)                  3.128135
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.749052     181.824678
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2018  POINT (8.27127 47.42103)                  2.519278
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.92844     146.452809
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2018', '8.27127', '47.42103', '3.130889', '0.750041', '182.01951']
# POT Data:
#  ['CAMELS', '2018', '8.27127', '47.42103', '3.128135', '0.749052', '181.824678']
# COM Data:
#  ['CAMELS', '2018', '8.27127', '47.42103', '2.519278', '0.92844', '146.452809']
# Results for Basin ID 2018 were successfully processed.
# Processing Basin ID: 2019
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2019  POINT (8.09203 46.74574)                  3.565409
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.760576     207.254577
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2019  POINT (8.09203 46.74574)                  3.325299
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.848963      193.26189
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2019  POINT (8.09203 46.74574)                  2.829182
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.951852     164.464682
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2019', '8.09203', '46.74574', '3.565409', '0.760576', '207.254577']
# POT Data:
#  ['CAMELS', '2019', '8.09203', '46.74574', '3.325299', '0.848963', '193.26189']
# COM Data:
#  ['CAMELS', '2019', '8.09203', '46.74574', '2.829182', '0.951852', '164.464682']
# Results for Basin ID 2019 were successfully processed.
# Processing Basin ID: 2020
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2020  POINT (9.00929 46.19377)                  3.994564
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.507565     232.284921
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2020  POINT (9.00929 46.19377)                  3.915202
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.471384     227.607897
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2020  POINT (9.00929 46.19377)                  2.312242
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.859246     134.422969
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2020', '9.00929', '46.19377', '3.994564', '0.507565', '232.284921']
# POT Data:
#  ['CAMELS', '2020', '9.00929', '46.19377', '3.915202', '0.471384', '227.607897']
# COM Data:
#  ['CAMELS', '2020', '9.00929', '46.19377', '2.312242', '0.859246', '134.422969']
# Results for Basin ID 2020 were successfully processed.
# Processing Basin ID: 2021
# Error while executing the notebook for Basin ID 2021: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2022
# Error while executing the notebook for Basin ID 2022: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2023
# Error while executing the notebook for Basin ID 2023: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2024
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2024  POINT (7.09128 46.12566)                  3.202287
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.841597      186.16193
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2024  POINT (7.09128 46.12566)                  3.328218
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.888862      193.42128
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2024  POINT (7.09128 46.12566)                   2.75979
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.946604     160.430609
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2024', '7.09128', '46.12566', '3.202287', '0.841597', '186.16193']
# POT Data:
#  ['CAMELS', '2024', '7.09128', '46.12566', '3.328218', '0.888862', '193.42128']
# COM Data:
#  ['CAMELS', '2024', '7.09128', '46.12566', '2.75979', '0.946604', '160.430609']
# Results for Basin ID 2024 were successfully processed.
# Processing Basin ID: 2025
# Error while executing the notebook for Basin ID 2025: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2026
# Error while executing the notebook for Basin ID 2026: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2027
# Error while executing the notebook for Basin ID 2027: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2028
# Error while executing the notebook for Basin ID 2028: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2029
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2029  POINT (7.28339 47.12206)                  2.683047
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.283767     155.811631
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2029  POINT (7.28339 47.12206)                  2.647878
#
#    circular_stats_regularity  mean_peak_doy
# 0                     0.3742     153.820299
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2029  POINT (7.28339 47.12206)                  2.046721
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.901615     118.982223
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2029', '7.28339', '47.12206', '2.683047', '0.283767', '155.811631']
# POT Data:
#  ['CAMELS', '2029', '7.28339', '47.12206', '2.647878', '0.3742', '153.820299']
# COM Data:
#  ['CAMELS', '2029', '7.28339', '47.12206', '2.046721', '0.901615', '118.982223']
# Results for Basin ID 2029 were successfully processed.
# Processing Basin ID: 2030
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2030  POINT (7.61183 46.76457)                  3.303898
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.768719     192.058302
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2030  POINT (7.61183 46.76457)                  3.089345
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.832816     179.542369
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2030  POINT (7.61183 46.76457)                  2.706727
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.945884     157.347012
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2030', '7.61183', '46.76457', '3.303898', '0.768719', '192.058302']
# POT Data:
#  ['CAMELS', '2030', '7.61183', '46.76457', '3.089345', '0.832816', '179.542369']
# COM Data:
#  ['CAMELS', '2030', '7.61183', '46.76457', '2.706727', '0.945884', '157.347012']
# Results for Basin ID 2030 were successfully processed.
# Processing Basin ID: 2031
# Error while executing the notebook for Basin ID 2031: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2032
# Error while executing the notebook for Basin ID 2032: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2033
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2033  POINT (9.20635 46.77581)                  3.552387
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.670266     206.512403
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2033  POINT (9.20635 46.77581)                  3.188509
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.753115     185.308692
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2033  POINT (9.20635 46.77581)                  2.605965
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.930844     151.488281
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2033', '9.20635', '46.77581', '3.552387', '0.670266', '206.512403']
# POT Data:
#  ['CAMELS', '2033', '9.20635', '46.77581', '3.188509', '0.753115', '185.308692']
# COM Data:
#  ['CAMELS', '2033', '9.20635', '46.77581', '2.605965', '0.930844', '151.488281']
# Results for Basin ID 2033 were successfully processed.
# Processing Basin ID: 2034
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2034  POINT (6.93607 46.83591)                   0.43914
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.605065      25.632017
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2034  POINT (6.93607 46.83591)                  0.410716
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.448945      23.954872
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2034  POINT (6.93607 46.83591)                  0.895078
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.870475       52.03583
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2034', '6.93607', '46.83591', '0.43914', '0.605065', '25.632017']
# POT Data:
#  ['CAMELS', '2034', '6.93607', '46.83591', '0.410716', '0.448945', '23.954872']
# COM Data:
#  ['CAMELS', '2034', '6.93607', '46.83591', '0.895078', '0.870475', '52.03583']
# Results for Basin ID 2034 were successfully processed.
# Processing Basin ID: 2041
# Error while executing the notebook for Basin ID 2041: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2043
# Error while executing the notebook for Basin ID 2043: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2044
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2044  POINT (8.68198 47.59652)                  3.071299
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.091401     177.882285
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2044  POINT (8.68198 47.59652)                  2.369753
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.086082     137.436798
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2044  POINT (8.68198 47.59652)                  1.675237
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.861644      97.390335
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2044', '8.68198', '47.59652', '3.071299', '0.091401', '177.882285']
# POT Data:
#  ['CAMELS', '2044', '8.68198', '47.59652', '2.369753', '0.086082', '137.436798']
# COM Data:
#  ['CAMELS', '2044', '8.68198', '47.59652', '1.675237', '0.861644', '97.390335']
# Results for Basin ID 2044 were successfully processed.
# Processing Basin ID: 2053
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2053  POINT (7.06275 46.09768)                  2.947002
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.84886     171.330939
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2053  POINT (7.06275 46.09768)                  2.913502
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.901629     169.332039
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2053  POINT (7.06275 46.09768)                   2.62007
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.927969     152.321706
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2053', '7.06275', '46.09768', '2.947002', '0.84886', '171.330939']
# POT Data:
#  ['CAMELS', '2053', '7.06275', '46.09768', '2.913502', '0.901629', '169.332039']
# COM Data:
#  ['CAMELS', '2053', '7.06275', '46.09768', '2.62007', '0.927969', '152.321706']
# Results for Basin ID 2053 were successfully processed.
# Processing Basin ID: 2056
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2056  POINT (8.62057 46.88391)                   3.37672
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.70047     196.313406
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2056  POINT (8.62057 46.88391)                  3.076985
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.837359     178.827125
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2056  POINT (8.62057 46.88391)                  2.830926
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.94889     164.565528
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2056', '8.62057', '46.88391', '3.37672', '0.70047', '196.313406']
# POT Data:
#  ['CAMELS', '2056', '8.62057', '46.88391', '3.076985', '0.837359', '178.827125']
# COM Data:
#  ['CAMELS', '2056', '8.62057', '46.88391', '2.830926', '0.94889', '164.565528']
# Results for Basin ID 2056 were successfully processed.
# Processing Basin ID: 2063
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2063  POINT (7.83062 47.26659)                  1.862981
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.175655     108.179167
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2063  POINT (7.83062 47.26659)                   2.50779
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.34072     145.662099
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2063  POINT (7.83062 47.26659)                  1.951009
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.899604     113.418167
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2063', '7.83062', '47.26659', '1.862981', '0.175655', '108.179167']
# POT Data:
#  ['CAMELS', '2063', '7.83062', '47.26659', '2.50779', '0.34072', '145.662099']
# COM Data:
#  ['CAMELS', '2063', '7.83062', '47.26659', '1.951009', '0.899604', '113.418167']
# Results for Basin ID 2063 were successfully processed.
# Processing Basin ID: 2066
# Error while executing the notebook for Basin ID 2066: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2067
#
# Raw outputs:
# Annual Max:    source Station_ID                   geometry  circular_stats_theta_rad  \
# 0  CAMELS       2067  POINT (10.46542 46.88578)                  3.160553
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.805763     183.740771
# POT:    source Station_ID                   geometry  circular_stats_theta_rad  \
# 0  CAMELS       2067  POINT (10.46542 46.88578)                  3.058857
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.881751     177.792368
# COM:    source Station_ID                   geometry  circular_stats_theta_rad  \
# 0  CAMELS       2067  POINT (10.46542 46.88578)                  2.743347
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.944528     159.476213
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2067', '10.46542', '46.88578', '3.160553', '0.805763', '183.740771']
# POT Data:
#  ['CAMELS', '2067', '10.46542', '46.88578', '3.058857', '0.881751', '177.792368']
# COM Data:
#  ['CAMELS', '2067', '10.46542', '46.88578', '2.743347', '0.944528', '159.476213']
# Results for Basin ID 2067 were successfully processed.
# Processing Basin ID: 2068
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2068  POINT (8.91033 46.16339)                  3.929778
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.485806     228.501952
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2068  POINT (8.91033 46.16339)                  4.055275
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.480458     235.812035
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2068  POINT (8.91033 46.16339)                  2.259377
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.819361     131.338941
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2068', '8.91033', '46.16339', '3.929778', '0.485806', '228.501952']
# POT Data:
#  ['CAMELS', '2068', '8.91033', '46.16339', '4.055275', '0.480458', '235.812035']
# COM Data:
#  ['CAMELS', '2068', '8.91033', '46.16339', '2.259377', '0.819361', '131.338941']
# Results for Basin ID 2068 were successfully processed.
# Processing Basin ID: 2070
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2070  POINT (7.74880 46.95444)                  3.254719
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.310191     189.228453
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2070  POINT (7.74880 46.95444)                  2.706038
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.263476     157.239248
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       2070  POINT (7.74880 46.95444)                  1.849261
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.865143     107.503983
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '2070', '7.74880', '46.95444', '3.254719', '0.310191', '189.228453']
# POT Data:
#  ['CAMELS', '2070', '7.74880', '46.95444', '2.706038', '0.263476', '157.239248']
# COM Data:
#  ['CAMELS', '2070', '7.74880', '46.95444', '1.849261', '0.865143', '107.503983']
# Results for Basin ID 2070 were successfully processed.
# Processing Basin ID: 2072
# Error while executing the notebook for Basin ID 2072: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
#    1741     basins_regimes_gdf['mean_peak_doy'] = doy_stations
#    1742
# -> 1743     return basins_regimes_gdf, theta_rad
#    1744
#    1745 ###
#
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
# UnboundLocalError: local variable 'theta_rad' referenced before assignment
#
# Processing Basin ID: 2073
# Error while executing the notebook for Basin ID 2073: An error occurred while executing the following cell:
# ------------------
# # Regime classification based on streamflow annual maxima (flag=1)
# regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#
# display(regime_annualmax_gdf)
# print(theta_rad_events_annualmax)
# ------------------
#
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-f832bed16c58> in <module>
#       1 # Regime classification based on streamflow annual maxima (flag=1)
# ----> 2 regime_annualmax_gdf, theta_rad_events_annualmax = regime_classification(Qobs_testbasin_ds, start_water_year=(month_start_water_year_default, day_start_water_year_default), max_gap_days=max_gap_days_default, flag=1)
#       3
#       4 display(regime_annualmax_gdf)
#       5 print(theta_rad_events_annualmax)
#
# ~\PycharmProjects\FROSTBYTE\scripts\functions.py in regime_classification(streamflow_obs, start_water_year, max_gap_days, flag)
# ...
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.577941      29.649937
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5030  POINT (6.84362 47.15465)                  0.423658
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.547495       24.71824
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5030  POINT (6.84362 47.15465)                  0.919352
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.93984      53.428154
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '5030', '6.84362', '47.15465', '0.510262', '0.577941', '29.649937']
# POT Data:
#  ['CAMELS', '5030', '6.84362', '47.15465', '0.423658', '0.547495', '24.71824']
# COM Data:
#  ['CAMELS', '5030', '6.84362', '47.15465', '0.919352', '0.93984', '53.428154']
# Results for Basin ID 5030 were successfully processed.
# Processing Basin ID: 5031
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5031  POINT (6.85932 45.91586)                  3.593907
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.895453     208.903319
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5031  POINT (6.85932 45.91586)                  3.548792
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.930064     206.311229
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5031  POINT (6.85932 45.91586)                  3.251062
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.995726     188.963616
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '5031', '6.85932', '45.91586', '3.593907', '0.895453', '208.903319']
# POT Data:
#  ['CAMELS', '5031', '6.85932', '45.91586', '3.548792', '0.930064', '206.311229']
# COM Data:
#  ['CAMELS', '5031', '6.85932', '45.91586', '3.251062', '0.995726', '188.963616']
# Results for Basin ID 5031 were successfully processed.
# Processing Basin ID: 5032
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5032  POINT (6.95048 47.27163)                  0.419726
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.611323      24.521658
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5032  POINT (6.95048 47.27163)                  0.449653
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.494309      26.217723
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       5032  POINT (6.95048 47.27163)                   0.99245
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.87712      57.697581
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '5032', '6.95048', '47.27163', '0.419726', '0.611323', '24.521658']
# POT Data:
#  ['CAMELS', '5032', '6.95048', '47.27163', '0.449653', '0.494309', '26.217723']
# COM Data:
#  ['CAMELS', '5032', '6.95048', '47.27163', '0.99245', '0.87712', '57.697581']
# Results for Basin ID 5032 were successfully processed.
# Processing Basin ID: 6001
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6001  POINT (7.95439 45.96974)                  3.153865
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.504958     183.496409
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6001  POINT (7.95439 45.96974)                   3.07686
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.768665     178.871867
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6001  POINT (7.95439 45.96974)                  3.110407
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.972367     180.864001
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6001', '7.95439', '45.96974', '3.153865', '0.504958', '183.496409']
# POT Data:
#  ['CAMELS', '6001', '7.95439', '45.96974', '3.07686', '0.768665', '178.871867']
# COM Data:
#  ['CAMELS', '6001', '7.95439', '45.96974', '3.110407', '0.972367', '180.864001']
# Results for Basin ID 6001 were successfully processed.
# Processing Basin ID: 6002
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6002  POINT (8.13208 45.98593)                   3.20492
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.477765     186.352181
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6002  POINT (8.13208 45.98593)                  3.103334
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.540569     180.268583
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6002  POINT (8.13208 45.98593)                  2.451452
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.994092     142.510414
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6002', '8.13208', '45.98593', '3.20492', '0.477765', '186.352181']
# POT Data:
#  ['CAMELS', '6002', '8.13208', '45.98593', '3.103334', '0.540569', '180.268583']
# COM Data:
#  ['CAMELS', '6002', '8.13208', '45.98593', '2.451452', '0.994092', '142.510414']
# Results for Basin ID 6002 were successfully processed.
# Processing Basin ID: 6003
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6003  POINT (8.25741 46.06772)                  5.901034
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.156908     342.218781
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6003  POINT (8.25741 46.06772)                  2.580338
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.290328     149.806775
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6003  POINT (8.25741 46.06772)                  1.777845
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.638273     103.371348
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6003', '8.25741', '46.06772', '5.901034', '0.156908', '342.218781']
# POT Data:
#  ['CAMELS', '6003', '8.25741', '46.06772', '2.580338', '0.290328', '149.806775']
# COM Data:
#  ['CAMELS', '6003', '8.25741', '46.06772', '1.777845', '0.638273', '103.371348']
# Results for Basin ID 6003 were successfully processed.
# Processing Basin ID: 6004
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6004  POINT (8.27402 46.12178)                  4.401768
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.447056     255.904709
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6004  POINT (8.27402 46.12178)                  2.796686
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.356646     162.371422
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6004  POINT (8.27402 46.12178)                  2.147296
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.898895     124.849921
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6004', '8.27402', '46.12178', '4.401768', '0.447056', '255.904709']
# POT Data:
#  ['CAMELS', '6004', '8.27402', '46.12178', '2.796686', '0.356646', '162.371422']
# COM Data:
#  ['CAMELS', '6004', '8.27402', '46.12178', '2.147296', '0.898895', '124.849921']
# Results for Basin ID 6004 were successfully processed.
# Processing Basin ID: 6005
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6005  POINT (8.30627 46.11259)                  4.321748
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.128718     251.340927
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6005  POINT (8.30627 46.11259)                  2.869986
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.499327     166.704821
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6005  POINT (8.30627 46.11259)                  2.147881
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.958339     124.871805
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6005', '8.30627', '46.11259', '4.321748', '0.128718', '251.340927']
# POT Data:
#  ['CAMELS', '6005', '8.30627', '46.11259', '2.869986', '0.499327', '166.704821']
# COM Data:
#  ['CAMELS', '6005', '8.30627', '46.11259', '2.147881', '0.958339', '124.871805']
# Results for Basin ID 6005 were successfully processed.
# Processing Basin ID: 6006
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6006  POINT (8.32385 46.18081)                  2.758838
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.596398     160.418447
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6006  POINT (8.32385 46.18081)                  2.640676
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.70287     153.400974
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6006  POINT (8.32385 46.18081)                   2.45699
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.995462     142.803058
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6006', '8.32385', '46.18081', '2.758838', '0.596398', '160.418447']
# POT Data:
#  ['CAMELS', '6006', '8.32385', '46.18081', '2.640676', '0.70287', '153.400974']
# COM Data:
#  ['CAMELS', '6006', '8.32385', '46.18081', '2.45699', '0.995462', '142.803058']
# Results for Basin ID 6006 were successfully processed.
# Processing Basin ID: 6007
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6007  POINT (8.42180 45.97476)                  3.778094
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.19492     219.606713
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6007  POINT (8.42180 45.97476)                  4.189218
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.19989     243.878406
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6007  POINT (8.42180 45.97476)                  2.149667
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.841291     124.973039
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6007', '8.42180', '45.97476', '3.778094', '0.19492', '219.606713']
# POT Data:
#  ['CAMELS', '6007', '8.42180', '45.97476', '4.189218', '0.19989', '243.878406']
# COM Data:
#  ['CAMELS', '6007', '8.42180', '45.97476', '2.149667', '0.841291', '124.973039']
# Results for Basin ID 6007 were successfully processed.
# Processing Basin ID: 6008
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6008  POINT (8.43422 45.92688)                  5.192775
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.282467     301.794678
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6008  POINT (8.43422 45.92688)                  5.431235
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.185599     315.944454
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6008  POINT (8.43422 45.92688)                  1.842883
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.740757     107.161259
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6008', '8.43422', '45.92688', '5.192775', '0.282467', '301.794678']
# POT Data:
#  ['CAMELS', '6008', '8.43422', '45.92688', '5.431235', '0.185599', '315.944454']
# COM Data:
#  ['CAMELS', '6008', '8.43422', '45.92688', '1.842883', '0.740757', '107.161259']
# Results for Basin ID 6008 were successfully processed.
# Processing Basin ID: 6009
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6009  POINT (8.52540 45.95661)                  4.043136
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.162594     235.309329
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6009  POINT (8.52540 45.95661)                   4.60108
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.265927     267.705653
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6009  POINT (8.52540 45.95661)                  2.014056
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.572202     117.163246
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6009', '8.52540', '45.95661', '4.043136', '0.162594', '235.309329']
# POT Data:
#  ['CAMELS', '6009', '8.52540', '45.95661', '4.60108', '0.265927', '267.705653']
# COM Data:
#  ['CAMELS', '6009', '8.52540', '45.95661', '2.014056', '0.572202', '117.163246']
# Results for Basin ID 6009 were successfully processed.
# Processing Basin ID: 6010
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6010  POINT (8.57883 45.94133)                  2.420427
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.198962     140.164167
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6010  POINT (8.57883 45.94133)                  4.851944
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.149858     283.199991
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6010  POINT (8.57883 45.94133)                  1.834037
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.892961     106.680523
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6010', '8.57883', '45.94133', '2.420427', '0.198962', '140.164167']
# POT Data:
#  ['CAMELS', '6010', '8.57883', '45.94133', '4.851944', '0.149858', '283.199991']
# COM Data:
#  ['CAMELS', '6010', '8.57883', '45.94133', '1.834037', '0.892961', '106.680523']
# Results for Basin ID 6010 were successfully processed.
# Processing Basin ID: 6011
#
# Raw outputs:
# Annual Max:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6011  POINT (8.64892 45.69666)                  5.219852
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.393055     302.968918
# POT:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6011  POINT (8.64892 45.69666)                  5.419547
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.786468     314.800064
# COM:    source Station_ID                  geometry  circular_stats_theta_rad  \
# 0  CAMELS       6011  POINT (8.64892 45.69666)                  1.922551
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.864491     111.814848
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['CAMELS', '6011', '8.64892', '45.69666', '5.219852', '0.393055', '302.968918']
# POT Data:
#  ['CAMELS', '6011', '8.64892', '45.69666', '5.419547', '0.786468', '314.800064']
# COM Data:
#  ['CAMELS', '6011', '8.64892', '45.69666', '1.922551', '0.864491', '111.814848']
# Results for Basin ID 6011 were successfully processed.
# All results have been successfully exported as CSV files.

# %%
import pandas as pd

# Lade die CSV-Dateien
file_path1 = '../CH_data/CH_output_data/regime_annualmax_data.csv'
file_path2 = '../CH_data/CH_output_data/regime_COM_data.csv'
file_path3 = '../CH_data/CH_output_data/regime_POT_data.csv'

regime_annualmax_data = pd.read_csv(file_path1)
regime_COM_data = pd.read_csv(file_path2)
regime_POT_data = pd.read_csv(file_path3)

nival_start_doy_default = 60 # nival regime starting day of year, corresponds to the 1st of March
nival_end_doy_default = 213  # nival regime ending day of year, corresponds to the 1st of August
nival_regularity_threshold_default = 0.65

# Filtere die Daten nach 'mean_peak_doy' zwischen 150 und 200
filtered_annualmax = regime_annualmax_data[(regime_annualmax_data['mean_peak_doy'] >= nival_start_doy_default) & (regime_annualmax_data['mean_peak_doy'] <= nival_end_doy_default) & (regime_annualmax_data['circular_stats_regularity']>= nival_regularity_threshold_default)]
filtered_COM = regime_COM_data[(regime_COM_data['mean_peak_doy'] >= nival_start_doy_default) & (regime_COM_data['mean_peak_doy'] <= nival_end_doy_default) & (regime_annualmax_data['circular_stats_regularity']>= nival_regularity_threshold_default)]
filtered_POT = regime_POT_data[(regime_POT_data['mean_peak_doy'] >= nival_start_doy_default) & (regime_POT_data['mean_peak_doy'] <= nival_end_doy_default) & (regime_annualmax_data['circular_stats_regularity']>= nival_regularity_threshold_default)]

# Finde die Schnittmenge der Station_IDs in allen drei gefilterten DataFrames
nival_basins_id = set(filtered_annualmax['Station_ID']).intersection(set(filtered_COM['Station_ID'])).intersection(set(filtered_POT['Station_ID']))

# Gebe die Station_IDs aus, die in allen drei Metriken die Bedingung erfüllen
print("Nival basins:")
print(nival_basins_id)

# Umwandeln in ein DataFrame
df = pd.DataFrame(nival_basins_id, columns=['Station_ID'])

# Speichern als CSV
df.to_csv('../CH_data/CH_output_data/nival_basins_id.csv', index=False)
# Out:
# Nival basins:
# {2304, 2053, 2056, 2185, 2319, 3031, 2067, 2327, 2200, 2457, 2462, 5025, 5027, 2469, 5031, 2473, 2346, 2219, 4010, 2351, 2607, 2481, 2355, 2104, 2105, 2617, 2491, 2620, 2109, 2110, 2239, 3001, 3003, 3005, 3006, 2244, 2117, 2372, 3008, 3009, 3010, 3018, 3019, 3021, 2256, 3025, 3027, 3030, 2262, 2135, 2263, 3033, 2009, 2265, 2011, 2268, 2141, 2269, 3032, 2018, 2019, 2403, 2150, 2024, 2152, 2030, 2288, 2033, 2418, 2419, 2299}
