# %% [markdown]
# ## Run Regime Classification
# Run regime classification for all CAMELS basins. Make sure that the 3 last cells in 1_Regime classification are the outputs (no empty cells)!

# %%
#Calculates the 3 metrics (annual max, POT and COM= for each basin
import numpy as np
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor
import pandas as pd
import warnings
import io
import re  # For regular expression operations

# Suppress warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Load the Basin IDs
#ids = ["2327", "2463"]

file_path = 'N:/gebhyd/3_Hyv/Diplomanden/2_Running/L_Nuesch/data_sweden/CAMELS_SW/2023-173-1/data/catchment properties/catchment properties/catchments_physical_properties.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)
gauge_id = data['ID']
ids = gauge_id.tolist()


def clean_data(raw_data):
    """
    Clean the extracted data list by removing unwanted elements and parentheses.
    """
    cleaned_data = []
    
    for item in raw_data:
        if item == '0' or item == 'POINT':
            continue  # Skip '0' and 'POINT'
        if '(' in item:  # For latitude
            item = item.replace('(', '')  # Remove '('
        if ')' in item:  # For longitude
            item = item.replace(')', '')  # Remove ')'
        
        cleaned_data.append(item)  # Add the cleaned item to the list
    
    return cleaned_data

def extract_data_array(raw_output):
    """
    Extract data from the raw output string into an array without headers.
    """
    # Split the raw output into lines
    lines = raw_output.strip().splitlines()
    
    # Use a regex to capture only the relevant lines for DataFrame
    data_lines = []
    
    for line in lines:
        # Ignore lines that don't start with a valid pattern
        if re.match(r'^\d+', line) or 'CAMELS' in line:  # Keeping lines starting with digits or containing 'CAMELS'
            # Remove unwanted characters and split into elements
            cleaned_line = re.sub(r'\\', '', line)  # Remove backslashes
            elements = cleaned_line.split()  # Split by whitespace
            data_lines.append(elements)

    # Flatten the list of lists into a single list, removing headers
    return [item for sublist in data_lines for item in sublist]

def run_regime_classification(ids):
    # Load the rc_simulation Notebook
    notebook_file = '../notebooks/1_RegimeClassification.ipynb'
    
    # Initialize lists to store all results
    regime_annualmax_data = []
    regime_POT_data = []
    regime_COM_data = []

    for basin_id in ids:
        print(f"Processing Basin ID: {basin_id}")  # Log the current Basin ID
        with open(notebook_file) as f:
            nb = nbformat.read(f, as_version=4)

        # Set basin_id in the notebook as test_basin_id
        replacement_done = False  # Flag to track if replacement is done
        
        for cell in nb.cells:
            if cell.cell_type == 'code' and not replacement_done:
                # Search for the line that contains 'test_basin_id ='
                if 'test_basin_id' in cell.source:
                    # Replace the entire line where test_basin_id is defined
                    cell_lines = cell.source.split('\n')
                    for i, line in enumerate(cell_lines):
                        if 'test_basin_id' in line:
                            # Replace the line with the new basin_id assignment
                            cell_lines[i] = f"test_basin_id = '{basin_id}'  # Set basin_id for testing"
                            replacement_done = True
                            break  # Exit the loop after the first replacement
                    # Re-join the cell source code
                    cell.source = '\n'.join(cell_lines)

        # Execute the notebook
        ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
        try:
            ep.preprocess(nb, {'metadata': {'path': './'}})

            # Extract the outputs from the last 3 cells
            regime_annualmax_gdf = nb.cells[-3].outputs[0]['data']['text/plain']
            regime_POT_gdf = nb.cells[-2].outputs[0]['data']['text/plain']
            regime_COM_gdf = nb.cells[-1].outputs[0]['data']['text/plain']

            # Debug: Print raw outputs
            print("\nRaw outputs:")
            print("Annual Max:", regime_annualmax_gdf)
            print("POT:", regime_POT_gdf)
            print("COM:", regime_COM_gdf)

            # Extract data as arrays without headers
            annualmax_data = extract_data_array(regime_annualmax_gdf)
            POT_data = extract_data_array(regime_POT_gdf)
            COM_data = extract_data_array(regime_COM_gdf)

            # Clean the extracted data
            cleaned_annualmax_data = clean_data(annualmax_data)
            cleaned_POT_data = clean_data(POT_data)
            cleaned_COM_data = clean_data(COM_data)

            # Debug: Print cleaned arrays
            print("\nCleaned Data Arrays:")
            print("Annual Max Data:\n", cleaned_annualmax_data)
            print("POT Data:\n", cleaned_POT_data)
            print("COM Data:\n", cleaned_COM_data)

            # Append the current basin's cleaned data to the final results
            regime_annualmax_data.append(cleaned_annualmax_data)  # Add Basin ID
            regime_POT_data.append(cleaned_POT_data)  # Add Basin ID
            regime_COM_data.append(cleaned_COM_data)  # Add Basin ID

            print(f"Results for Basin ID {basin_id} were successfully processed.")

        except Exception as e:
            print(f"Error while executing the notebook for Basin ID {basin_id}: {e}")

    # Save the results as CSV files with headers
    header = 'source,Station_ID,lon,lat,circular_stats_theta_rad,circular_stats_regularity,mean_peak_doy'
    #np.savetxt('../CH_data/CH_output_data/regime_annualmax_data.csv', regime_annualmax_data, delimiter=',', fmt='%s')
    np.savetxt('../CAMELS_SW/output_data/regime_annualmax_data.csv', regime_annualmax_data, delimiter=',', fmt='%s', header=header, comments='')
    np.savetxt('../CAMELS_SW/output_data/regime_POT_data.csv', regime_POT_data, delimiter=',', fmt='%s', header=header, comments='')
    np.savetxt('../CAMELS_SW/output_data/regime_COM_data.csv', regime_COM_data, delimiter=',', fmt='%s', header=header, comments='')

    print("All results have been successfully exported as CSV files.")

# Start the function
run_regime_classification(ids)
# Out:
# Processing Basin ID: 5
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0          5  POINT (21.97580 68.03560)                  2.559673
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.955321     148.800068
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0          5  POINT (21.97580 68.03560)                  2.910585
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.838617     169.198708
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0          5  POINT (21.97580 68.03560)                   2.67257
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.95226     155.362903
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['5', '21.97580', '68.03560', '2.559673', '0.955321', '148.800068']
# POT Data:
#  ['5', '21.97580', '68.03560', '2.910585', '0.838617', '169.198708']
# COM Data:
#  ['5', '21.97580', '68.03560', '2.67257', '0.95226', '155.362903']
# Results for Basin ID 5 were successfully processed.
# Processing Basin ID: 20
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         20  POINT (21.96770 66.02222)                  2.380848
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.933049      138.40695
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         20  POINT (21.96770 66.02222)                  2.443022
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.906726     142.009391
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         20  POINT (21.96770 66.02222)                  2.427874
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.955924     141.137403
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['20', '21.96770', '66.02222', '2.380848', '0.933049', '138.40695']
# POT Data:
#  ['20', '21.96770', '66.02222', '2.443022', '0.906726', '142.009391']
# COM Data:
#  ['20', '21.96770', '66.02222', '2.427874', '0.955924', '141.137403']
# Results for Basin ID 20 were successfully processed.
# Processing Basin ID: 37
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         37  POINT (17.79092 66.52728)                  2.995177
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.941868     174.116219
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         37  POINT (17.79092 66.52728)                  3.296378
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.864882     191.617341
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         37  POINT (17.79092 66.52728)                  3.002012
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.959832     174.511242
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['37', '17.79092', '66.52728', '2.995177', '0.941868', '174.116219']
# POT Data:
#  ['37', '17.79092', '66.52728', '3.296378', '0.864882', '191.617341']
# COM Data:
#  ['37', '17.79092', '66.52728', '3.002012', '0.959832', '174.511242']
# Results for Basin ID 37 were successfully processed.
# Processing Basin ID: 97
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         97  POINT (15.70920 62.81930)                  2.516991
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.775774     146.314063
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         97  POINT (15.70920 62.81930)                  3.090676
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.508998     179.603934
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0         97  POINT (15.70920 62.81930)                  2.353766
#
#    circular_stats_regularity  mean_peak_doy
# 0                     0.8908     136.833059
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['97', '15.70920', '62.81930', '2.516991', '0.775774', '146.314063']
# POT Data:
#  ['97', '15.70920', '62.81930', '3.090676', '0.508998', '179.603934']
# COM Data:
#  ['97', '15.70920', '62.81930', '2.353766', '0.8908', '136.833059']
# Results for Basin ID 97 were successfully processed.
# Processing Basin ID: 138
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        138  POINT (16.46590 59.32210)                  0.680724
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.30935      39.539571
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        138  POINT (16.46590 59.32210)                  0.983775
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.067996      56.825125
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        138  POINT (16.46590 59.32210)                  1.104409
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.82211      64.200031
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['138', '16.46590', '59.32210', '0.680724', '0.30935', '39.539571']
# POT Data:
#  ['138', '16.46590', '59.32210', '0.983775', '0.067996', '56.825125']
# COM Data:
#  ['138', '16.46590', '59.32210', '1.104409', '0.82211', '64.200031']
# Results for Basin ID 138 were successfully processed.
# Processing Basin ID: 186
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        186  POINT (14.74939 56.19665)                  1.097728
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.553506      63.810006
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        186  POINT (14.74939 56.19665)                   0.86816
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.32343      50.456151
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        186  POINT (14.74939 56.19665)                  1.184604
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.881437      68.862906
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['186', '14.74939', '56.19665', '1.097728', '0.553506', '63.810006']
# POT Data:
#  ['186', '14.74939', '56.19665', '0.86816', '0.32343', '50.456151']
# COM Data:
#  ['186', '14.74939', '56.19665', '1.184604', '0.881437', '68.862906']
# Results for Basin ID 186 were successfully processed.
# Processing Basin ID: 200
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        200  POINT (14.58602 57.24186)                  1.180487
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.550693      68.619977
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        200  POINT (14.58602 57.24186)                  1.282607
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.321986      74.482952
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        200  POINT (14.58602 57.24186)                  1.329142
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.821518      77.269247
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['200', '14.58602', '57.24186', '1.180487', '0.550693', '68.619977']
# POT Data:
#  ['200', '14.58602', '57.24186', '1.282607', '0.321986', '74.482952']
# COM Data:
#  ['200', '14.58602', '57.24186', '1.329142', '0.821518', '77.269247']
# Results for Basin ID 200 were successfully processed.
# Processing Basin ID: 257
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        257  POINT (11.68325 58.46484)                  0.159693
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.520159       9.374206
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        257  POINT (11.68325 58.46484)                  0.032575
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.472736       2.090705
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        257  POINT (11.68325 58.46484)                  0.701702
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.817128      40.802872
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['257', '11.68325', '58.46484', '0.159693', '0.520159', '9.374206']
# POT Data:
#  ['257', '11.68325', '58.46484', '0.032575', '0.472736', '2.090705']
# COM Data:
#  ['257', '11.68325', '58.46484', '0.701702', '0.817128', '40.802872']
# Results for Basin ID 257 were successfully processed.
# Processing Basin ID: 364
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        364  POINT (13.14225 57.61002)                  0.443144
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.521462      25.787481
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        364  POINT (13.14225 57.61002)                  0.526641
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.325438      30.659475
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        364  POINT (13.14225 57.61002)                  1.028975
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.871023      59.814323
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['364', '13.14225', '57.61002', '0.443144', '0.521462', '25.787481']
# POT Data:
#  ['364', '13.14225', '57.61002', '0.526641', '0.325438', '30.659475']
# COM Data:
#  ['364', '13.14225', '57.61002', '1.028975', '0.871023', '59.814323']
# Results for Basin ID 364 were successfully processed.
# Processing Basin ID: 591
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        591  POINT (18.21740 66.87620)                  2.934987
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.919243     170.615958
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        591  POINT (18.21740 66.87620)                   3.04194
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.909316     176.821861
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        591  POINT (18.21740 66.87620)                  3.013687
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.960366     175.188739
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['591', '18.21740', '66.87620', '2.934987', '0.919243', '170.615958']
# POT Data:
#  ['591', '18.21740', '66.87620', '3.04194', '0.909316', '176.821861']
# COM Data:
#  ['591', '18.21740', '66.87620', '3.013687', '0.960366', '175.188739']
# Results for Basin ID 591 were successfully processed.
# Processing Basin ID: 654
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        654  POINT (13.00679 61.30927)                  2.433115
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.79318     141.430102
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        654  POINT (13.00679 61.30927)                  2.439244
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.799476     141.758411
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        654  POINT (13.00679 61.30927)                  2.321981
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.944585     134.981577
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['654', '13.00679', '61.30927', '2.433115', '0.79318', '141.430102']
# POT Data:
#  ['654', '13.00679', '61.30927', '2.439244', '0.799476', '141.758411']
# COM Data:
#  ['654', '13.00679', '61.30927', '2.321981', '0.944585', '134.981577']
# Results for Basin ID 654 were successfully processed.
# Processing Basin ID: 736
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        736  POINT (14.61999 56.12177)                  0.933442
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.647915      54.272327
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        736  POINT (14.61999 56.12177)                   0.77161
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.560372      44.884079
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        736  POINT (14.61999 56.12177)                   0.92351
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.881438      53.691286
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['736', '14.61999', '56.12177', '0.933442', '0.647915', '54.272327']
# POT Data:
#  ['736', '14.61999', '56.12177', '0.77161', '0.560372', '44.884079']
# COM Data:
#  ['736', '14.61999', '56.12177', '0.92351', '0.881438', '53.691286']
# Results for Basin ID 736 were successfully processed.
# Processing Basin ID: 740
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        740  POINT (15.52504 61.36344)                  2.425025
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.618977      140.95767
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        740  POINT (15.52504 61.36344)                  2.535168
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.240651     147.183244
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        740  POINT (15.52504 61.36344)                  1.800502
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.86748     104.665458
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['740', '15.52504', '61.36344', '2.425025', '0.618977', '140.95767']
# POT Data:
#  ['740', '15.52504', '61.36344', '2.535168', '0.240651', '147.183244']
# COM Data:
#  ['740', '15.52504', '61.36344', '1.800502', '0.86748', '104.665458']
# Results for Basin ID 740 were successfully processed.
# Processing Basin ID: 751
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        751  POINT (11.53711 58.87717)                  0.139519
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.573234        8.31018
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        751  POINT (11.53711 58.87717)                  0.208858
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.417994      12.285816
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        751  POINT (11.53711 58.87717)                   0.70076
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.841532      40.766046
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['751', '11.53711', '58.87717', '0.139519', '0.573234', '8.31018']
# POT Data:
#  ['751', '11.53711', '58.87717', '0.208858', '0.417994', '12.285816']
# COM Data:
#  ['751', '11.53711', '58.87717', '0.70076', '0.841532', '40.766046']
# Results for Basin ID 751 were successfully processed.
# Processing Basin ID: 855
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        855  POINT (16.16019 57.01130)                  1.099384
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.591813       63.90508
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        855  POINT (16.16019 57.01130)                  1.250071
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.177778      72.502824
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0        855  POINT (16.16019 57.01130)                  1.234262
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.826283      71.752735
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['855', '16.16019', '57.01130', '1.099384', '0.591813', '63.90508']
# POT Data:
#  ['855', '16.16019', '57.01130', '1.250071', '0.177778', '72.502824']
# COM Data:
#  ['855', '16.16019', '57.01130', '1.234262', '0.826283', '71.752735']
# Results for Basin ID 855 were successfully processed.
# Processing Basin ID: 1069
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1069  POINT (14.12533 56.66226)                  1.093681
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.655067      63.562331
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1069  POINT (14.12533 56.66226)                  1.356632
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.325363      78.811666
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1069  POINT (14.12533 56.66226)                  1.361726
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.857969      79.158359
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1069', '14.12533', '56.66226', '1.093681', '0.655067', '63.562331']
# POT Data:
#  ['1069', '14.12533', '56.66226', '1.356632', '0.325363', '78.811666']
# COM Data:
#  ['1069', '14.12533', '56.66226', '1.361726', '0.857969', '79.158359']
# Results for Basin ID 1069 were successfully processed.
# Processing Basin ID: 1083
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1083  POINT (12.12667 62.63917)                  2.454897
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.955774     142.709167
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1083  POINT (12.12667 62.63917)                  2.638459
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.872953     153.370137
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1083  POINT (12.12667 62.63917)                  2.521871
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.960552     146.600344
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1083', '12.12667', '62.63917', '2.454897', '0.955774', '142.709167']
# POT Data:
#  ['1083', '12.12667', '62.63917', '2.638459', '0.872953', '153.370137']
# COM Data:
#  ['1083', '12.12667', '62.63917', '2.521871', '0.960552', '146.600344']
# Results for Basin ID 1083 were successfully processed.
# Processing Basin ID: 1123
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1123  POINT (21.80688 66.17126)                  2.361516
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.933621     137.282885
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1123  POINT (21.80688 66.17126)                  2.416838
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.913804     140.488109
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1123  POINT (21.80688 66.17126)                  2.414813
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.955307     140.377811
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1123', '21.80688', '66.17126', '2.361516', '0.933621', '137.282885']
# POT Data:
#  ['1123', '21.80688', '66.17126', '2.416838', '0.913804', '140.488109']
# COM Data:
#  ['1123', '21.80688', '66.17126', '2.414813', '0.955307', '140.377811']
# Results for Basin ID 1123 were successfully processed.
# Processing Basin ID: 1166
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1166  POINT (13.13975 57.43626)                  0.295271
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.591199      17.225083
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1166  POINT (13.13975 57.43626)                  0.284005
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.45439       16.61154
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1166  POINT (13.13975 57.43626)                  0.880692
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.857218      51.194187
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1166', '13.13975', '57.43626', '0.295271', '0.591199', '17.225083']
# POT Data:
#  ['1166', '13.13975', '57.43626', '0.284005', '0.45439', '16.61154']
# COM Data:
#  ['1166', '13.13975', '57.43626', '0.880692', '0.857218', '51.194187']
# Results for Basin ID 1166 were successfully processed.
# Processing Basin ID: 1169
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1169  POINT (12.61090 62.54540)                   2.46868
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.95228     143.510123
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1169  POINT (12.61090 62.54540)                  2.577926
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.914665     149.857038
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1169  POINT (12.61090 62.54540)                  2.532717
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.960613     147.231108
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1169', '12.61090', '62.54540', '2.46868', '0.95228', '143.510123']
# POT Data:
#  ['1169', '12.61090', '62.54540', '2.577926', '0.914665', '149.857038']
# COM Data:
#  ['1169', '12.61090', '62.54540', '2.532717', '0.960613', '147.231108']
# Results for Basin ID 1169 were successfully processed.
# Processing Basin ID: 1171
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1171  POINT (12.43971 61.81998)                   2.35114
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.918119     136.677258
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1171  POINT (12.43971 61.81998)                  2.430183
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.885945     141.239925
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1171  POINT (12.43971 61.81998)                  2.368518
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.954975     137.686496
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1171', '12.43971', '61.81998', '2.35114', '0.918119', '136.677258']
# POT Data:
#  ['1171', '12.43971', '61.81998', '2.430183', '0.885945', '141.239925']
# COM Data:
#  ['1171', '12.43971', '61.81998', '2.368518', '0.954975', '137.686496']
# Results for Basin ID 1171 were successfully processed.
# Processing Basin ID: 1221
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1221  POINT (14.06251 58.59727)                  0.936665
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.430614      54.376137
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1221  POINT (14.06251 58.59727)                  0.685403
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.332527      39.857731
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1221  POINT (14.06251 58.59727)                  1.135109
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.857431      65.991237
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1221', '14.06251', '58.59727', '0.936665', '0.430614', '54.376137']
# POT Data:
#  ['1221', '14.06251', '58.59727', '0.685403', '0.332527', '39.857731']
# COM Data:
#  ['1221', '14.06251', '58.59727', '1.135109', '0.857431', '65.991237']
# Results for Basin ID 1221 were successfully processed.
# Processing Basin ID: 1236
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1236  POINT (13.04199 58.32006)                  0.536965
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.480165      31.265103
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1236  POINT (13.04199 58.32006)                  0.499904
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.39088      29.130631
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1236  POINT (13.04199 58.32006)                  0.836963
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.820668        48.6593
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1236', '13.04199', '58.32006', '0.536965', '0.480165', '31.265103']
# POT Data:
#  ['1236', '13.04199', '58.32006', '0.499904', '0.39088', '29.130631']
# COM Data:
#  ['1236', '13.04199', '58.32006', '0.836963', '0.820668', '48.6593']
# Results for Basin ID 1236 were successfully processed.
# Processing Basin ID: 1243
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1243  POINT (12.35161 58.62106)                  0.328056
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.425754      19.184496
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1243  POINT (12.35161 58.62106)                  0.337666
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.424273       19.75741
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1243  POINT (12.35161 58.62106)                  0.913945
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.85979      53.127268
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1243', '12.35161', '58.62106', '0.328056', '0.425754', '19.184496']
# POT Data:
#  ['1243', '12.35161', '58.62106', '0.337666', '0.424273', '19.75741']
# COM Data:
#  ['1243', '12.35161', '58.62106', '0.913945', '0.85979', '53.127268']
# Results for Basin ID 1243 were successfully processed.
# Processing Basin ID: 1273
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1273  POINT (16.69940 58.85850)                  1.393455
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.553136      80.951036
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1273  POINT (16.69940 58.85850)                  1.855858
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.092944     107.543218
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1273  POINT (16.69940 58.85850)                   1.55116
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.868452      90.169642
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1273', '16.69940', '58.85850', '1.393455', '0.553136', '80.951036']
# POT Data:
#  ['1273', '16.69940', '58.85850', '1.855858', '0.092944', '107.543218']
# COM Data:
#  ['1273', '16.69940', '58.85850', '1.55116', '0.868452', '90.169642']
# Results for Basin ID 1273 were successfully processed.
# Processing Basin ID: 1309
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1309  POINT (13.01340 63.73550)                  2.415024
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.608921     140.427119
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1309  POINT (13.01340 63.73550)                  2.521804
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.721899      146.60541
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1309  POINT (13.01340 63.73550)                  2.462237
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.954423     143.135205
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1309', '13.01340', '63.73550', '2.415024', '0.608921', '140.427119']
# POT Data:
#  ['1309', '13.01340', '63.73550', '2.521804', '0.721899', '146.60541']
# COM Data:
#  ['1309', '13.01340', '63.73550', '2.462237', '0.954423', '143.135205']
# Results for Basin ID 1309 were successfully processed.
# Processing Basin ID: 1328
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1328  POINT (12.78616 63.43911)                  2.536961
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.94893     147.479475
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1328  POINT (12.78616 63.43911)                  2.952127
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.690493     171.607055
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1328  POINT (12.78616 63.43911)                  2.581792
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.957585     150.083717
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1328', '12.78616', '63.43911', '2.536961', '0.94893', '147.479475']
# POT Data:
#  ['1328', '12.78616', '63.43911', '2.952127', '0.690493', '171.607055']
# COM Data:
#  ['1328', '12.78616', '63.43911', '2.581792', '0.957585', '150.083717']
# Results for Basin ID 1328 were successfully processed.
# Processing Basin ID: 1341
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1341  POINT (14.11151 64.06513)                  2.501871
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.892348     145.430435
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1341  POINT (14.11151 64.06513)                  2.564565
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.897372     149.098688
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1341  POINT (14.11151 64.06513)                  2.496055
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.95642     145.100936
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1341', '14.11151', '64.06513', '2.501871', '0.892348', '145.430435']
# POT Data:
#  ['1341', '14.11151', '64.06513', '2.564565', '0.897372', '149.098688']
# COM Data:
#  ['1341', '14.11151', '64.06513', '2.496055', '0.95642', '145.100936']
# Results for Basin ID 1341 were successfully processed.
# Processing Basin ID: 1375
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1375  POINT (11.65307 58.79010)                    0.0503
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.526617       3.105022
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1375  POINT (11.65307 58.79010)                  0.309846
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.421419      18.137149
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1375  POINT (11.65307 58.79010)                  0.806942
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.843414      46.923508
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1375', '11.65307', '58.79010', '0.0503', '0.526617', '3.105022']
# POT Data:
#  ['1375', '11.65307', '58.79010', '0.309846', '0.421419', '18.137149']
# COM Data:
#  ['1375', '11.65307', '58.79010', '0.806942', '0.843414', '46.923508']
# Results for Basin ID 1375 were successfully processed.
# Processing Basin ID: 1378
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1378  POINT (16.75027 63.64228)                  2.464751
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.810123     143.294352
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1378  POINT (16.75027 63.64228)                  3.127049
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.384326     181.699914
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1378  POINT (16.75027 63.64228)                   2.24365
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.873873      130.43174
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1378', '16.75027', '63.64228', '2.464751', '0.810123', '143.294352']
# POT Data:
#  ['1378', '16.75027', '63.64228', '3.127049', '0.384326', '181.699914']
# COM Data:
#  ['1378', '16.75027', '63.64228', '2.24365', '0.873873', '130.43174']
# Results for Basin ID 1378 were successfully processed.
# Processing Basin ID: 1403
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1403  POINT (18.82720 66.65260)                  2.777086
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.900172     161.440735
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1403  POINT (18.82720 66.65260)                  3.188866
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.798595     185.357063
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1403  POINT (18.82720 66.65260)                  2.793824
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.951608     162.409844
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1403', '18.82720', '66.65260', '2.777086', '0.900172', '161.440735']
# POT Data:
#  ['1403', '18.82720', '66.65260', '3.188866', '0.798595', '185.357063']
# COM Data:
#  ['1403', '18.82720', '66.65260', '2.793824', '0.951608', '162.409844']
# Results for Basin ID 1403 were successfully processed.
# Processing Basin ID: 1480
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1480  POINT (19.88800 65.34200)                  2.501603
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.896363     145.417257
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1480  POINT (19.88800 65.34200)                  2.965709
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.658304     172.362288
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1480  POINT (19.88800 65.34200)                  2.522252
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.947259     146.624281
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1480', '19.88800', '65.34200', '2.501603', '0.896363', '145.417257']
# POT Data:
#  ['1480', '19.88800', '65.34200', '2.965709', '0.658304', '172.362288']
# COM Data:
#  ['1480', '19.88800', '65.34200', '2.522252', '0.947259', '146.624281']
# Results for Basin ID 1480 were successfully processed.
# Processing Basin ID: 1537
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1537  POINT (14.23936 64.83855)                  2.769879
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.907453     161.021874
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1537  POINT (14.23936 64.83855)                  2.845302
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.912947     165.406012
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1537  POINT (14.23936 64.83855)                  2.797924
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.958882     162.648073
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1537', '14.23936', '64.83855', '2.769879', '0.907453', '161.021874']
# POT Data:
#  ['1537', '14.23936', '64.83855', '2.845302', '0.912947', '165.406012']
# COM Data:
#  ['1537', '14.23936', '64.83855', '2.797924', '0.958882', '162.648073']
# Results for Basin ID 1537 were successfully processed.
# Processing Basin ID: 1575
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1575  POINT (13.12440 56.71570)                  0.141488
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.532737        8.33898
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1575  POINT (13.12440 56.71570)                  0.073721
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.521662        4.39216
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1575  POINT (13.12440 56.71570)                  0.765689
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.822782       44.53271
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1575', '13.12440', '56.71570', '0.141488', '0.532737', '8.33898']
# POT Data:
#  ['1575', '13.12440', '56.71570', '0.073721', '0.521662', '4.39216']
# COM Data:
#  ['1575', '13.12440', '56.71570', '0.765689', '0.822782', '44.53271']
# Results for Basin ID 1575 were successfully processed.
# Processing Basin ID: 1583
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1583  POINT (18.29905 63.43351)                   2.27477
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.819153      132.24599
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1583  POINT (18.29905 63.43351)                  2.563463
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.552607     148.932957
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1583  POINT (18.29905 63.43351)                  2.148635
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.920865     124.905683
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1583', '18.29905', '63.43351', '2.27477', '0.819153', '132.24599']
# POT Data:
#  ['1583', '18.29905', '63.43351', '2.563463', '0.552607', '148.932957']
# COM Data:
#  ['1583', '18.29905', '63.43351', '2.148635', '0.920865', '124.905683']
# Results for Basin ID 1583 were successfully processed.
# Processing Basin ID: 1609
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1609  POINT (18.96120 65.12930)                  2.376339
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.937099       138.1359
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1609  POINT (18.96120 65.12930)                  3.064719
#
#    circular_stats_regularity  mean_peak_doy
# 0                     0.5887     178.124048
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1609  POINT (18.96120 65.12930)                  2.426086
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.95144     141.033885
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1609', '18.96120', '65.12930', '2.376339', '0.937099', '138.1359']
# POT Data:
#  ['1609', '18.96120', '65.12930', '3.064719', '0.5887', '178.124048']
# COM Data:
#  ['1609', '18.96120', '65.12930', '2.426086', '0.95144', '141.033885']
# Results for Basin ID 1609 were successfully processed.
# Processing Basin ID: 1622
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1622  POINT (15.56943 57.61942)                  1.181298
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.503495      68.657953
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1622  POINT (15.56943 57.61942)                  0.924689
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.401103      53.742182
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1622  POINT (15.56943 57.61942)                   1.21209
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.810736      70.472139
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1622', '15.56943', '57.61942', '1.181298', '0.503495', '68.657953']
# POT Data:
#  ['1622', '15.56943', '57.61942', '0.924689', '0.401103', '53.742182']
# COM Data:
#  ['1622', '15.56943', '57.61942', '1.21209', '0.810736', '70.472139']
# Results for Basin ID 1622 were successfully processed.
# Processing Basin ID: 1623
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1623  POINT (12.31848 58.20556)                  0.265727
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.517176      15.582848
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1623  POINT (12.31848 58.20556)                  0.219356
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.493528      12.862845
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1623  POINT (12.31848 58.20556)                  0.625064
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.830444      36.345091
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1623', '12.31848', '58.20556', '0.265727', '0.517176', '15.582848']
# POT Data:
#  ['1623', '12.31848', '58.20556', '0.219356', '0.493528', '12.862845']
# COM Data:
#  ['1623', '12.31848', '58.20556', '0.625064', '0.830444', '36.345091']
# Results for Basin ID 1623 were successfully processed.
# Processing Basin ID: 1635
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1635  POINT (13.11019 56.14344)                  0.475533
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.502442      27.724515
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1635  POINT (13.11019 56.14344)                  0.294402
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.526935      17.185415
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1635  POINT (13.11019 56.14344)                  0.771754
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.85133      44.862862
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1635', '13.11019', '56.14344', '0.475533', '0.502442', '27.724515']
# POT Data:
#  ['1635', '13.11019', '56.14344', '0.294402', '0.526935', '17.185415']
# COM Data:
#  ['1635', '13.11019', '56.14344', '0.771754', '0.85133', '44.862862']
# Results for Basin ID 1635 were successfully processed.
# Processing Basin ID: 1639
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1639  POINT (13.95731 58.35891)                  0.943997
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.591831      54.878083
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1639  POINT (13.95731 58.35891)                  0.612116
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.453538      35.631734
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1639  POINT (13.95731 58.35891)                   0.99571
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.874982       57.88451
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1639', '13.95731', '58.35891', '0.943997', '0.591831', '54.878083']
# POT Data:
#  ['1639', '13.95731', '58.35891', '0.612116', '0.453538', '35.631734']
# COM Data:
#  ['1639', '13.95731', '58.35891', '0.99571', '0.874982', '57.88451']
# Results for Basin ID 1639 were successfully processed.
# Processing Basin ID: 1662
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1662  POINT (14.31490 58.71300)                    0.8844
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.478537       51.43699
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1662  POINT (14.31490 58.71300)                  0.893784
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.23184       51.89699
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1662  POINT (14.31490 58.71300)                  1.093019
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.794726      63.544127
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1662', '14.31490', '58.71300', '0.8844', '0.478537', '51.43699']
# POT Data:
#  ['1662', '14.31490', '58.71300', '0.893784', '0.23184', '51.89699']
# COM Data:
#  ['1662', '14.31490', '58.71300', '1.093019', '0.794726', '63.544127']
# Results for Basin ID 1662 were successfully processed.
# Processing Basin ID: 1673
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1673  POINT (14.90595 65.82945)                  2.700849
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.918263     157.008059
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1673  POINT (14.90595 65.82945)                  2.779782
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.95123     161.608964
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1673  POINT (14.90595 65.82945)                  2.746823
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.95794     159.677945
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1673', '14.90595', '65.82945', '2.700849', '0.918263', '157.008059']
# POT Data:
#  ['1673', '14.90595', '65.82945', '2.779782', '0.95123', '161.608964']
# COM Data:
#  ['1673', '14.90595', '65.82945', '2.746823', '0.95794', '159.677945']
# Results for Basin ID 1673 were successfully processed.
# Processing Basin ID: 1685
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1685  POINT (16.27510 64.16590)                   2.70412
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.800269     157.199092
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1685  POINT (16.27510 64.16590)                   2.96956
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.664934      172.58488
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1685  POINT (16.27510 64.16590)                  2.300321
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.919382     133.719609
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1685', '16.27510', '64.16590', '2.70412', '0.800269', '157.199092']
# POT Data:
#  ['1685', '16.27510', '64.16590', '2.96956', '0.664934', '172.58488']
# COM Data:
#  ['1685', '16.27510', '64.16590', '2.300321', '0.919382', '133.719609']
# Results for Basin ID 1685 were successfully processed.
# Processing Basin ID: 1697
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1697  POINT (14.13618 55.94571)                  0.681038
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.55881      39.666615
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1697  POINT (14.13618 55.94571)                  0.642563
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.463246      37.397987
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1697  POINT (14.13618 55.94571)                  0.867442
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.898151      50.431262
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1697', '14.13618', '55.94571', '0.681038', '0.55881', '39.666615']
# POT Data:
#  ['1697', '14.13618', '55.94571', '0.642563', '0.463246', '37.397987']
# COM Data:
#  ['1697', '14.13618', '55.94571', '0.867442', '0.898151', '50.431262']
# Results for Basin ID 1697 were successfully processed.
# Processing Basin ID: 1740
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1740  POINT (22.30599 66.58073)                  2.357153
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.930367     137.029552
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1740  POINT (22.30599 66.58073)                  2.529807
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.819421     147.056348
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1740  POINT (22.30599 66.58073)                  2.446947
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.947148     142.246204
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1740', '22.30599', '66.58073', '2.357153', '0.930367', '137.029552']
# POT Data:
#  ['1740', '22.30599', '66.58073', '2.529807', '0.819421', '147.056348']
# COM Data:
#  ['1740', '22.30599', '66.58073', '2.446947', '0.947148', '142.246204']
# Results for Basin ID 1740 were successfully processed.
# Processing Basin ID: 1762
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1762  POINT (13.42338 60.79558)                  2.452314
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.695864     142.565127
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1762  POINT (13.42338 60.79558)                  2.524649
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.599254     146.674962
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1762  POINT (13.42338 60.79558)                   2.24034
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.932961     130.235909
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1762', '13.42338', '60.79558', '2.452314', '0.695864', '142.565127']
# POT Data:
#  ['1762', '13.42338', '60.79558', '2.524649', '0.599254', '146.674962']
# COM Data:
#  ['1762', '13.42338', '60.79558', '2.24034', '0.932961', '130.235909']
# Results for Basin ID 1762 were successfully processed.
# Processing Basin ID: 1780
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1780  POINT (22.16980 68.37060)                  2.520283
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.92308     146.505209
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1780  POINT (22.16980 68.37060)                  3.060875
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.725358     177.935575
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       1780  POINT (22.16980 68.37060)                  2.609263
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.941566     151.682633
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['1780', '22.16980', '68.37060', '2.520283', '0.92308', '146.505209']
# POT Data:
#  ['1780', '22.16980', '68.37060', '3.060875', '0.725358', '177.935575']
# COM Data:
#  ['1780', '22.16980', '68.37060', '2.609263', '0.941566', '151.682633']
# Results for Basin ID 1780 were successfully processed.
# Processing Basin ID: 2020
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       2020  POINT (16.93578 58.81578)                  1.440708
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.452535      83.693744
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       2020  POINT (16.93578 58.81578)                  1.476386
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.120995      85.575799
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       2020  POINT (16.93578 58.81578)                   1.47002
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.86121      85.452457
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['2020', '16.93578', '58.81578', '1.440708', '0.452535', '83.693744']
# POT Data:
#  ['2020', '16.93578', '58.81578', '1.476386', '0.120995', '85.575799']
# COM Data:
#  ['2020', '16.93578', '58.81578', '1.47002', '0.86121', '85.452457']
# Results for Basin ID 2020 were successfully processed.
# Processing Basin ID: 2203
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       2203  POINT (14.89475 60.48221)                  2.523846
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.613432     146.680682
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       2203  POINT (14.89475 60.48221)                  2.739922
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.431768     159.143832
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0       2203  POINT (14.89475 60.48221)                  1.992933
#
#    circular_stats_regularity  mean_peak_doy
# 0                    0.88288     115.852859
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['2203', '14.89475', '60.48221', '2.523846', '0.613432', '146.680682']
# POT Data:
#  ['2203', '14.89475', '60.48221', '2.739922', '0.431768', '159.143832']
# COM Data:
#  ['2203', '14.89475', '60.48221', '1.992933', '0.88288', '115.852859']
# Results for Basin ID 2203 were successfully processed.
# Processing Basin ID: 20002
#
# Raw outputs:
# Annual Max:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0      20002  POINT (16.45087 57.14329)                  1.200876
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.566655      69.797108
# POT:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0      20002  POINT (16.45087 57.14329)                  1.007837
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.424318      58.566295
# COM:   Station_ID                   geometry  circular_stats_theta_rad  \
# 0      20002  POINT (16.45087 57.14329)                   1.23022
#
#    circular_stats_regularity  mean_peak_doy
# 0                   0.849528      71.520645
#
# Cleaned Data Arrays:
# Annual Max Data:
#  ['20002', '16.45087', '57.14329', '1.200876', '0.566655', '69.797108']
# POT Data:
#  ['20002', '16.45087', '57.14329', '1.007837', '0.424318', '58.566295']
# COM Data:
#  ['20002', '16.45087', '57.14329', '1.23022', '0.849528', '71.520645']
# Results for Basin ID 20002 were successfully processed.
# All results have been successfully exported as CSV files.

# %%
#extracts the nival basins
import pandas as pd

# Lade die CSV-Dateien
file_path1 = '../CH_data/CH_output_data/regime_annualmax_data.csv'
file_path2 = '../CH_data/CH_output_data/regime_COM_data.csv'
file_path3 = '../CH_data/CH_output_data/regime_POT_data.csv'

regime_annualmax_data = pd.read_csv(file_path1)
regime_COM_data = pd.read_csv(file_path2)
regime_POT_data = pd.read_csv(file_path3)

nival_start_doy_default = 60 # nival regime starting day of year, corresponds to the 1st of March
nival_end_doy_default = 213  # nival regime ending day of year, corresponds to the 1st of August
nival_regularity_threshold_default = 0.65

# Filtere die Daten nach 'mean_peak_doy' zwischen 150 und 200
filtered_annualmax = regime_annualmax_data[(regime_annualmax_data['mean_peak_doy'] >= nival_start_doy_default) & (regime_annualmax_data['mean_peak_doy'] <= nival_end_doy_default) & (regime_annualmax_data['circular_stats_regularity']>= nival_regularity_threshold_default)]
filtered_COM = regime_COM_data[(regime_COM_data['mean_peak_doy'] >= nival_start_doy_default) & (regime_COM_data['mean_peak_doy'] <= nival_end_doy_default) & (regime_COM_data['circular_stats_regularity']>= nival_regularity_threshold_default)]
filtered_POT = regime_POT_data[(regime_POT_data['mean_peak_doy'] >= nival_start_doy_default) & (regime_POT_data['mean_peak_doy'] <= nival_end_doy_default) & (regime_POT_data['circular_stats_regularity']>= nival_regularity_threshold_default)]

# Finde die Schnittmenge der Station_IDs in allen drei gefilterten DataFrames
nival_basins_id = set(filtered_annualmax['Station_ID']).intersection(set(filtered_COM['Station_ID'])).intersection(set(filtered_POT['Station_ID']))

# Gebe die Station_IDs aus, die in allen drei Metriken die Bedingung erfüllen
print("Nival basins:")
print(nival_basins_id)

# Umwandeln in ein DataFrame
df = pd.DataFrame(nival_basins_id, columns=['Station_ID'])

# Speichern als CSV
df.to_csv('../CH_data/CH_output_data/nival_basins_id.csv', index=False)
# Out:
# Nival basins:
# {2304, 2053, 2056, 2185, 2319, 3031, 2067, 2327, 2200, 2457, 2462, 5025, 5027, 2469, 5031, 2473, 2346, 2219, 4010, 2351, 2607, 2481, 2355, 2104, 2105, 2617, 2491, 2620, 2109, 2110, 3001, 3003, 3006, 3009, 2244, 2117, 2372, 3018, 2256, 3025, 3030, 2262, 2135, 2263, 3033, 2009, 2265, 2011, 2268, 2141, 2269, 3032, 2018, 2019, 2403, 2150, 2024, 2152, 2030, 2288, 2033, 2418, 2419, 2299}
